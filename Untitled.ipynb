# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## membaca datasheet

# %%
df = pd.read_csv('botak.csv')

# %%
df
# Out:
#       umur jenis_kelamin       pekerjaan      provinsi          gaji  \
# 0     42.0     Laki-laki             PNS        Padang  7.864005e+06
# 1     33.0     Laki-laki  Pegawai swasta  Palangkaraya  6.492662e+06
# 2     59.0     Laki-laki       Freelance        Serang  8.086303e+06
# 3     38.0     Laki-laki  Pegawai swasta     Gorontalo  1.147321e+07
# 4     33.0     Perempuan       Freelance  Tanjungselor  1.475942e+07
# ...    ...           ...             ...           ...           ...
# 7986  31.0     Laki-laki  Pegawai swasta        Padang  2.911963e+07
# 7987  40.0     Perempuan  Pegawai swasta   Banjarmasin  8.955173e+06
# 7988  43.0     Perempuan             PNS       Mataram  4.022652e+06
# 7989  29.0     Laki-laki  Pegawai swasta        Serang  5.801753e+06
# 7990  55.0     Laki-laki  Pegawai swasta        Padang  8.518947e+06
#
#       is_menikah  is_keturunan      berat      tinggi            sampo  \
# ...

# %%
# 1. Diagram Histogram Distribusi Usia Responden
plt.figure(figsize=(8, 5))
plt.hist(df['umur'].dropna(), bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Usia')
plt.ylabel('Jumlah Responden')
plt.title('Distribusi Usia Responden')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# 3. Scatter Plot Hubungan antara Gaji dan Probabilitas Botak
plt.figure(figsize=(8, 5))
sns.scatterplot(x='gaji', y='botak_prob', data=df, alpha=0.5, color='purple')
plt.xlabel('Gaji')
plt.ylabel('Probabilitas Botak')
plt.title('Hubungan antara Gaji dan Probabilitas Botak')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
# 5. Scatter Plot Hubungan antara Tinggi dan Berat
plt.figure(figsize=(8, 5))
sns.scatterplot(x='tinggi', y='berat', data=df, alpha=0.5, color='orange')
plt.xlabel('Tinggi (cm)')
plt.ylabel('Berat (kg)')
plt.title('Hubungan antara Tinggi dan Berat')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
